# %%
import pandas as pd
import numpy as np

# %%
a=pd.DataFrame(np.arange(20).reshape(4,5),index=['c','a','d','b'])

# %%
a
# Out:
#     0   1   2   3   4
# c   0   1   2   3   4
# a   5   6   7   8   9
# d  10  11  12  13  14
# b  15  16  17  18  19

# %%
a.sort_index(axis=1,ascending=False)
# Out:
#     4   3   2   1   0
# c   4   3   2   1   0
# a   9   8   7   6   5
# d  14  13  12  11  10
# b  19  18  17  16  15

# %%
a.sort_values('a',axis=1)
# Out:
#     0   1   2   3   4
# c   0   1   2   3   4
# a   5   6   7   8   9
# d  10  11  12  13  14
# b  15  16  17  18  19

# %%
a
# Out:
#     0   1   2   3   4
# c   0   1   2   3   4
# a   5   6   7   8   9
# d  10  11  12  13  14
# b  15  16  17  18  19

# %%
b=a.index.append([5])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_51096/3933009892.py in <module>
# ----> 1 b=a.index.append([5])
#
# D:\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\indexes\base.py in append(self, other)
#    5113         for obj in to_concat:
#    5114             if not isinstance(obj, Index):
# -> 5115                 raise TypeError("all inputs must be Index")
#    5116
#    5117         names = {obj.name for obj in to_concat}
#
# TypeError: all inputs must be Index

# %%
a
# Out:
#     0   1   2   3   4
# c   0   1   2   3   4
# a   5   6   7   8   9
# d  10  11  12  13  14
# b  15  16  17  18  19

# %%
a.cumsum(axis=1)
# Out:
#     0   1   2   3   4
# c   0   1   3   6  10
# a   5  11  18  26  35
# d  10  21  33  46  60
# b  15  31  48  66  85
